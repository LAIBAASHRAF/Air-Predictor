# %% [markdown]
# <a href="https://colab.research.google.com/github/LAIBAASHRAF/Air-Predictor/blob/main/Emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# cat_dict={"Emotion":"category","Text":"category","Clean_Text":"category"}
# datasets1=pd.read_csv("sample_data/emotion_dataset1.csv",index_col="ID",dtype=cat_dict)

datasets=pd.read_csv("sample_data/emotion_dataset1.csv",index_col="ID",dtype={"Emotion":"category"})

#datasets.dtypes
print(datasets["Emotion"].nbytes)
print(datasets["Clean_Text"].nbytes)
print(datasets["Text"].nbytes)
# Out:
# 34856
# 278336
# 278336

# %%
datasets.head()
# Out:
#     Emotion                                               Text  \
# ID
# 0   neutral                                             Why ?
# 1       joy    Sage Act upgrade on my to do list for tommorow.
# 2   sadness  ON THE WAY TO MY HOMEGIRL BABY FUNERAL!!! MAN ...
# 3       joy   Such an eye ! The true hazel eye-and so brill...
# 4       joy  @Iluvmiasantos ugh babe.. hugggzzz for u .!  b...
#
#                                            Clean_Text
# ID
# 0                                                 NaN
# 1                      Sage Act upgrade list tommorow
# 2   WAY HOMEGIRL BABY FUNERAL MAN HATE FUNERALS SH...
# 3   eye  true hazel eyeand brilliant  Regular feat...
# 4     ugh babe hugggzzz u  babe naamazed nga ako e...

# %%
datasets.drop("Text",axis=1,inplace=True)
datasets.head()
# Out:
#     Emotion                                         Clean_Text
# ID
# 0   neutral                                                NaN
# 1       joy                     Sage Act upgrade list tommorow
# 2   sadness  WAY HOMEGIRL BABY FUNERAL MAN HATE FUNERALS SH...
# 3       joy  eye  true hazel eyeand brilliant  Regular feat...
# 4       joy    ugh babe hugggzzz u  babe naamazed nga ako e...

# %%
datasets["Clean_Text"].str.lower()
# Out:
# ID
# 0                                                      NaN
# 1                           sage act upgrade list tommorow
# 2        way homegirl baby funeral man hate funerals sh...
# 3        eye  true hazel eyeand brilliant  regular feat...
# 4          ugh babe hugggzzz u  babe naamazed nga ako e...
#                                ...
# 34787           gift hope like it hand wear  itll warm lol
# 34788           world didnt meso world definitely cnt away
# 34789                                    man robbed today
# 34790                            youu jealousy #losing you
# 34791                                think baby dream time
# Name: Clean_Text, Length: 34792, dtype: object

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34792 entries, 0 to 34791
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emotion     34792 non-null  category
#  1   Clean_Text  34326 non-null  object
# dtypes: category(1), object(1)
# memory usage: 578.0+ KB

# %%
datasets.describe()
# Out:
#        Emotion                                         Clean_Text
# count    34792                                              34326
# unique       8                                              30642
# top        joy  “  afraid tomorrow seen yesterday love today #...
# freq     11045                                                103

# %%
datasets.value_counts()
# Out:
# Emotion   Clean_Text
# fear      “  afraid tomorrow seen yesterday love today #less”                                       103
# neutral   Yes                                                                                        87
# fear      afraid tomorrow seen yesterday love today #less                                            56
#           quot  afraid tomorrow seen yesterday love today #lessquot                                  54
# surprise  RT follow   WIN 5 special collector items giving away Twitter friends #RT #WIN             36
#                                                                                                    ...
# joy       Finally writing music Im pumped                                                             1
#           Finally work 12 hours                                                                       1
#           Finally weekend starts time write again¸¸•*˚¨˚* ☆∗♥∗☆ first #ffs lovely people follow♡      1
# ...
